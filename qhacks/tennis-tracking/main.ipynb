# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('drive/MyDrive/tennis-tracking-main')

# %%
# !pip install --upgrade setuptools
# Out:
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (69.0.3)
# ERROR: Operation cancelled by user

# %%
# !pip install filterpy sktime
# Out:
# Requirement already satisfied: filterpy in /usr/local/lib/python3.10/dist-packages (1.4.5)
# Collecting sktime
#   Using cached sktime-0.26.0-py3-none-any.whl (21.8 MB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from filterpy) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from filterpy) (1.11.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from filterpy) (3.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sktime) (23.2)
# Requirement already satisfied: pandas<2.2.0,>=1.1 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.5.3)
# Requirement already satisfied: scikit-base<0.8.0 in /usr/local/lib/python3.10/dist-packages (from sktime) (0.7.2)
# Requirement already satisfied: scikit-learn<1.5.0,>=0.24 in /usr/local/lib/python3.10/dist-packages (from sktime) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0,>=1.1->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.2.0,>=1.1->sktime) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.5.0,>=0.24->sktime) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.5.0,>=0.24->sktime) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->filterpy) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.2.0,>=1.1->sktime) (1.16.0)
# Installing collected packages: sktime
# Successfully installed sktime-0.26.0

# %%
 # !python3 predict_video.py --input_video_path=VideoInput/out2.mp4 --output_video_path=VideoOutput/video_output.mp4 --minimap=1 --bounce=0
# Out:
# 2024-02-03 15:10:14.900802: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-03 15:10:14.900852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-03 15:10:14.902175: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-03 15:10:14.909384: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-03 15:10:16.180532: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# fps : 25
# 2024-02-03 15:10:19.620898: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.621494: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.621698: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.622299: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.622514: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.622690: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.735010: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.735255: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.735426: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-02-03 15:10:19.735515: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-03 15:10:19.735673: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13949 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# layer24 output shape: 256 360 640
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3, 360, 640)]     0
#
#  conv2d (Conv2D)             (None, 64, 360, 640)      1792
#
#  activation (Activation)     (None, 64, 360, 640)      0
#
#  batch_normalization (Batch  (None, 64, 360, 640)      2560
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 64, 360, 640)      36928
#
#  activation_1 (Activation)   (None, 64, 360, 640)      0
#
#  batch_normalization_1 (Bat  (None, 64, 360, 640)      2560
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 64, 180, 320)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 180, 320)     73856
#
#  activation_2 (Activation)   (None, 128, 180, 320)     0
#
#  batch_normalization_2 (Bat  (None, 128, 180, 320)     1280
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 128, 180, 320)     147584
#
#  activation_3 (Activation)   (None, 128, 180, 320)     0
#
#  batch_normalization_3 (Bat  (None, 128, 180, 320)     1280
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 90, 160)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 256, 90, 160)      295168
#
#  activation_4 (Activation)   (None, 256, 90, 160)      0
#
#  batch_normalization_4 (Bat  (None, 256, 90, 160)      640
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 256, 90, 160)      590080
#
#  activation_5 (Activation)   (None, 256, 90, 160)      0
#
#  batch_normalization_5 (Bat  (None, 256, 90, 160)      640
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 256, 90, 160)      590080
#
#  activation_6 (Activation)   (None, 256, 90, 160)      0
#
#  batch_normalization_6 (Bat  (None, 256, 90, 160)      640
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 256, 45, 80)       0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 512, 45, 80)       1180160
#
#  activation_7 (Activation)   (None, 512, 45, 80)       0
#
#  batch_normalization_7 (Bat  (None, 512, 45, 80)       320
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 512, 45, 80)       2359808
#
#  activation_8 (Activation)   (None, 512, 45, 80)       0
#
#  batch_normalization_8 (Bat  (None, 512, 45, 80)       320
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 512, 45, 80)       2359808
#
#  activation_9 (Activation)   (None, 512, 45, 80)       0
#
#  batch_normalization_9 (Bat  (None, 512, 45, 80)       320
#  chNormalization)
#
#  up_sampling2d (UpSampling2  (None, 512, 90, 160)      0
#  D)
#
#  conv2d_10 (Conv2D)          (None, 256, 90, 160)      1179904
#
#  activation_10 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_10 (Ba  (None, 256, 90, 160)      640
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_11 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_11 (Ba  (None, 256, 90, 160)      640
#  tchNormalization)
#
#  conv2d_12 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_12 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_12 (Ba  (None, 256, 90, 160)      640
#  tchNormalization)
#
#  up_sampling2d_1 (UpSamplin  (None, 256, 180, 320)     0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 128, 180, 320)     295040
#
#  activation_13 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_13 (Ba  (None, 128, 180, 320)     1280
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 128, 180, 320)     147584
#
#  activation_14 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_14 (Ba  (None, 128, 180, 320)     1280
#  tchNormalization)
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 360, 640)     0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 64, 360, 640)      73792
#
#  activation_15 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_15 (Ba  (None, 64, 360, 640)      2560
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 64, 360, 640)      36928
#
#  activation_16 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_16 (Ba  (None, 64, 360, 640)      2560
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 256, 360, 640)     147712
#
#  activation_17 (Activation)  (None, 256, 360, 640)     0
#
#  batch_normalization_17 (Ba  (None, 256, 360, 640)     2560
#  tchNormalization)
#
#  reshape (Reshape)           (None, 256, 230400)       0
#
#  permute (Permute)           (None, 230400, 256)       0
#
#  activation_18 (Activation)  (None, 230400, 256)       0
#
# =================================================================
# Total params: 10719104 (40.89 MB)
# Trainable params: 10707744 (40.85 MB)
# Non-trainable params: 11360 (44.38 KB)
# _________________________________________________________________
# 2024-02-03 15:10:20.302202: W tensorflow/core/util/tensor_slice_reader.cc:98] Could not open WeightsTracknet/model.1: DATA_LOSS: not an sstable (bad magic number): perhaps your file is in a different file format and you need to use a different restore operator?
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Using device cuda
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Detecting the court and the players...
# BOXES  [array([289.59668, 488.28506, 380.29514, 629.8888 ], dtype=float32)]
# BIGGEST  [290. 488. 380. 630.]
# Finished!
# Tracking the ball: 0.0
# 2024-02-03 15:11:20.645412: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 1/1 [==============================] - 6s 6s/step
# Tracking the ball: 0.66
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 1.32
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 1.97
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 2.63
# 1/1 [==============================] - 0s 22ms/step
# Tracking the ball: 3.29
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 3.95
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 4.61
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 5.26
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 5.92
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 6.58
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 7.24
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 7.89
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 8.55
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 9.21
# 1/1 [==============================] - 0s 21ms/step
# Tracking the ball: 9.87
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 10.53
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 11.18
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 11.84
# 1/1 [==============================] - 0s 29ms/step
# Tracking the ball: 12.5
# 1/1 [==============================] - 0s 27ms/step
# Tracking the ball: 13.16
# 1/1 [==============================] - 0s 31ms/step
# Tracking the ball: 13.82
# 1/1 [==============================] - 0s 33ms/step
# Tracking the ball: 14.47
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 15.13
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 15.79
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 16.45
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 17.11
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 17.76
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 18.42
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 19.08
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 19.74
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 20.39
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 21.05
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 21.71
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 22.37
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 23.03
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 23.68
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 24.34
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 25.0
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 25.66
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 26.32
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 26.97
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 27.63
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 28.29
# 1/1 [==============================] - 0s 25ms/step
# Tracking the ball: 28.95
# 1/1 [==============================] - 0s 28ms/step
# Tracking the ball: 29.61
# 1/1 [==============================] - 0s 33ms/step
# Tracking the ball: 30.26
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 30.92
# 1/1 [==============================] - 0s 21ms/step
# Tracking the ball: 31.58
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 32.24
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 32.89
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 33.55
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 34.21
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 34.87
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 35.53
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 36.18
# 1/1 [==============================] - 0s 25ms/step
# Tracking the ball: 36.84
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 37.5
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 38.16
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 38.82
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 39.47
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 40.13
# 1/1 [==============================] - 0s 30ms/step
# Tracking the ball: 40.79
# 1/1 [==============================] - 0s 22ms/step
# Tracking the ball: 41.45
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 42.11
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 42.76
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 43.42
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 44.08
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 44.74
# 1/1 [==============================] - 0s 31ms/step
# Tracking the ball: 45.39
# 1/1 [==============================] - 0s 28ms/step
# Tracking the ball: 46.05
# 1/1 [==============================] - 0s 30ms/step
# Tracking the ball: 46.71
# 1/1 [==============================] - 0s 31ms/step
# Tracking the ball: 47.37
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 48.03
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 48.68
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 49.34
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 50.0
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 50.66
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 51.32
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 51.97
# 1/1 [==============================] - 0s 23ms/step
# Tracking the ball: 52.63
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 53.29
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 53.95
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 54.61
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 55.26
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 55.92
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 56.58
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 57.24
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 57.89
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 58.55
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 59.21
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 59.87
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 60.53
# 1/1 [==============================] - 0s 23ms/step
# Tracking the ball: 61.18
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 61.84
# 1/1 [==============================] - 0s 30ms/step
# Tracking the ball: 62.5
# 1/1 [==============================] - 0s 33ms/step
# Tracking the ball: 63.16
# 1/1 [==============================] - 0s 28ms/step
# Tracking the ball: 63.82
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 64.47
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 65.13
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 65.79
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 66.45
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 67.11
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 67.76
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 68.42
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 69.08
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 69.74
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 70.39
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 71.05
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 71.71
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 72.37
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 73.03
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 73.68
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 74.34
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 75.0
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 75.66
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 76.32
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 76.97
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 77.63
# 1/1 [==============================] - 0s 27ms/step
# Tracking the ball: 78.29
# 1/1 [==============================] - 0s 33ms/step
# Tracking the ball: 78.95
# 1/1 [==============================] - 0s 30ms/step
# Tracking the ball: 79.61
# 1/1 [==============================] - 0s 21ms/step
# Tracking the ball: 80.26
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 80.92
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 81.58
# 1/1 [==============================] - 0s 21ms/step
# Tracking the ball: 82.24
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 82.89
# 1/1 [==============================] - 0s 22ms/step
# Tracking the ball: 83.55
# 1/1 [==============================] - 0s 21ms/step
# Tracking the ball: 84.21
# 1/1 [==============================] - 0s 25ms/step
# Tracking the ball: 84.87
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 85.53
# 1/1 [==============================] - 0s 18ms/step
# Tracking the ball: 86.18
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 86.84
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 87.5
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 88.16
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 88.82
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 89.47
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 90.13
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 90.79
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 91.45
# 1/1 [==============================] - 0s 19ms/step
# Tracking the ball: 92.11
# 1/1 [==============================] - 0s 20ms/step
# Tracking the ball: 92.76
# 1/1 [==============================] - 0s 20ms/step
